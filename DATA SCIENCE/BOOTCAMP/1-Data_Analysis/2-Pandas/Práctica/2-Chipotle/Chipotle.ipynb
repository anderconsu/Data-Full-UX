# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and assign it to a variable called chipo.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. Name of the max valued product

# %%
df[['item_name', 'item_price']][df['item_price'] == df['item_price'].max()]
# Out:
#                 item_name item_price
# 607      Steak Salad Bowl     $9.39
# 1418  Barbacoa Salad Bowl     $9.39
# 1421  Barbacoa Salad Bowl     $9.39
# 1825  Barbacoa Salad Bowl     $9.39
# 1865  Carnitas Salad Bowl     $9.39
# 2600     Steak Salad Bowl     $9.39
# 2624     Steak Salad Bowl     $9.39
# 3098     Steak Salad Bowl     $9.39
# 3115  Carnitas Salad Bowl     $9.39
# 3356  Barbacoa Salad Bowl     $9.39
# 4036     Steak Salad Bowl     $9.39
# 4241     Steak Salad Bowl     $9.39
# 4390  Barbacoa Salad Bowl     $9.39
# 4391     Steak Salad Bowl     $9.39
# 4419     Steak Salad Bowl     $9.39
# 4547     Steak Salad Bowl     $9.39
# 4572     Steak Salad Bowl     $9.39

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df['item_price'].max()
# Out:
# '$9.39 '

# %%
df['item_price'].sort_values(ascending= False).head(20)
# Out:
# 2624    $9.39
# 4419    $9.39
# 4036    $9.39
# 1825    $9.39
# 3115    $9.39
# 4547    $9.39
# 3098    $9.39
# 4241    $9.39
# 1418    $9.39
# 4391    $9.39
# 4572    $9.39
# 2600    $9.39
# 607     $9.39
# 4390    $9.39
# 1865    $9.39
# 1421    $9.39
# 3356    $9.39
# 1789    $9.25
# 1771    $9.25
# 418     $9.25
# Name: item_price, dtype: object

# %%
# Metodo 1 de substitucion de valores str a float
df['item_price'] = df['item_price'].str.replace('$', '').astype(float)
# Out:
# C:\Users\migue\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#Metodo 2
# pd.to_numeric(df['item_price']) funciona como astype(float)

# %%
df['item_price'].str[1::].astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17544\4108081007.py in <module>
# ----> 1 df['item_price'].str[1::].astype(float)
#
# c:\Users\migue\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# c:\Users\migue\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %%
#Metodo 3
df['item_price'][0][1::]
# Out:
# '2.39 '

# %%
for i in range(len(df['item_price'])):
    df['item_price'][i] = df['item_price'][i][1::]

df['item_price']
# Out:
# C:\Users\migue\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df['item_price'] = df['item_price'].astype(float)

# %%
df['item_price'].max()
# Out:
# 44.25

# %%
df[df['item_price'] == df['item_price'].max()]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
df['unit_price'] = df['item_price'] / df['quantity']

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  unit_price
# 0                                                NaN        2.39        2.39
# 1                                       [Clementine]        3.39        3.39
# ...

# %%
df[['item_name', 'unit_price']][df['unit_price'] == df['unit_price'].max()]
# Out:
#                 item_name  unit_price
# 281      Steak Salad Bowl       11.89
# 606      Steak Salad Bowl       11.89
# 613      Steak Salad Bowl       11.89
# 749      Steak Salad Bowl       11.89
# 1132  Carnitas Salad Bowl       11.89
# 1159     Steak Salad Bowl       11.89
# 1229  Barbacoa Salad Bowl       11.89
# 1311     Steak Salad Bowl       11.89
# 1326  Barbacoa Salad Bowl       11.89
# 1505     Steak Salad Bowl       11.89
# 1571     Steak Salad Bowl       11.89
# 1590     Steak Salad Bowl       11.89
# 1816     Steak Salad Bowl       11.89
# 2401     Steak Salad Bowl       11.89
# 2439     Steak Salad Bowl       11.89
# 2442  Barbacoa Salad Bowl       11.89
# 2610  Carnitas Salad Bowl       11.89
# 2740     Steak Salad Bowl       11.89
# 2804     Steak Salad Bowl       11.89
# 2957     Steak Salad Bowl       11.89
# 3120     Steak Salad Bowl       11.89
# 3208  Barbacoa Salad Bowl       11.89
# 3350     Steak Salad Bowl       11.89
# 3493     Steak Salad Bowl       11.89
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
df['item_name'][df['unit_price'] > 10].nunique()
# Out:
# 25

# %% [markdown]
# Extra: Cuántos pedidos se han hecho con un producto de más de 10$

# %%
df['order_id'][df['unit_price'] > 10].nunique()
# Out:
# 787

# %% [markdown]
# ### Step 5. What is the price of each item? Get only item_name and unit_price

# %%
df[['item_name', 'unit_price']].drop_duplicates('item_name')
# Out:
#                                   item_name  unit_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl        8.49
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 16                          Chicken Burrito        8.49
# 18                              Canned Soda        1.09
# 21                         Barbacoa Burrito        8.99
# 27                         Carnitas Burrito        8.99
# 33                            Carnitas Bowl        8.99
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
df
# Out:
#       order_id  quantity            item_name  \
# 2442       970         1  Barbacoa Salad Bowl
# 2957      1176         1     Steak Salad Bowl
# 613        253         2     Steak Salad Bowl
# 2401       953         1     Steak Salad Bowl
# 281        123         2     Steak Salad Bowl
# ...        ...       ...                  ...
# 378        164         1          Canned Soda
# 1805       730         1          Canned Soda
# 2520      1001         1          Canned Soda
# 2981      1186         1        Bottled Water
# 646        267         1          Canned Soda
#
#                                      choice_description  item_price  \
# 2442  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...       11.89
# 2957  [Fresh Tomato Salsa, [Black Beans, Cheese, Gua...       11.89
# 613   [Tomatillo Red Chili Salsa, [Fajita Vegetables...       23.78
# 2401  [Fresh Tomato Salsa, [Fajita Vegetables, Guaca...       11.89
# ...

# %%
df.sort_values(by= 'unit_price', ascending= False, inplace= True)

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered? 2 ways

# %%
df[['item_name', 'quantity', 'item_price']][df['item_price'] == df['item_price'].max()]
# Out:
#                          item_name  quantity  item_price
# 3598  Chips and Fresh Tomato Salsa        15       44.25

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
len(df[['order_id', 'item_name']][df['item_name'].str.lower().str.contains('veggie salad bowl')].drop_duplicates('order_id'))
# Out:
# 18

# %%
df[['order_id', 'item_name']]
# Out:
#       order_id            item_name
# 2442       970  Barbacoa Salad Bowl
# 2957      1176     Steak Salad Bowl
# 613        253     Steak Salad Bowl
# 2401       953     Steak Salad Bowl
# 281        123     Steak Salad Bowl
# ...        ...                  ...
# 378        164          Canned Soda
# 1805       730          Canned Soda
# 2520      1001          Canned Soda
# 2981      1186        Bottled Water
# 646        267          Canned Soda
#
# [4622 rows x 2 columns]

# %%
df[['order_id', 'item_name']][df['item_name'].str.contains('Veggie Salad')]
# Out:
# 18

# %%
df['item_name'].value_counts().get('Veggie Salad Bowl')
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
df[['order_id', 'quantity', 'item_price']][(df['item_name'].str.contains('Canned Soda')) & (df['quantity'] > 1)]
# Out:
#       order_id  quantity  item_price
# 51          23         2        2.18
# 3152      1258         2        2.18
# 350        150         2        2.18
# 18           9         2        2.18
# 2135       859         2        2.18
# 2235       901         4        4.36
# 3592      1440         2        2.18
# 1092       450         2        2.18
# 162         73         2        2.18
# 1944       787         2        2.18
# 2905      1156         2        2.18
# 171         76         2        2.18
# 352        151         2        2.18
# 698        287         2        2.18
# 700        288         2        2.18
# 909        376         2        2.18
# 2906      1156         2        2.18
# 3866      1550         2        2.18
# 1091       450         2        2.18
# 3364      1349         2        2.18
