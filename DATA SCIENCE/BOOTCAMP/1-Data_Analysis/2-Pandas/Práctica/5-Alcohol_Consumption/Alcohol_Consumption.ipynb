# %% [markdown]
# # Ex - GroupBy

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks['continent'].unique()
# Out:
# array(['AS', 'EU', 'AF', nan, 'SA', 'OC'], dtype=object)

# %%
drinks[drinks['continent'].isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
drinks['continent'][drinks['country'].isin(['Canada', 'USA'])] = 'NA'
# Out:
# C:\Users\migue\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
drinks[drinks['continent'] == 'NA']
# Out:
#     country  beer_servings  spirit_servings  wine_servings  \
# 32   Canada            240              122            100
# 184     USA            249              158             84
#
#      total_litres_of_pure_alcohol continent
# 32                            8.2        NA
# 184                           8.7        NA

# %%
drinks[drinks['continent'].isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# 74                       Honduras             69               98
# ...

# %%
drinks['continent'][drinks['continent'].isnull()] = 'CA'
# Out:
# C:\Users\migue\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks[drinks['continent'] == 'CA']
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# 74                       Honduras             69               98
# ...

# %%
drinks['continent'].unique()
# Out:
# array(['AS', 'EU', 'AF', 'CA', 'SA', 'OC', 'NA'], dtype=object)

# %%
# drinks['continent'] = np.where(drinks['continent'].isin(['NA', 'SA', 'CA']), 'A', drinks['continent'])

# %%
# drinks['continent'].unique()

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks.groupby('continent').mean()[['beer_servings']].sort_values(by = 'beer_servings', ascending= False)
# Out:
#            beer_servings
# continent
# NA            244.500000
# EU            193.777778
# SA            175.083333
# CA            136.000000
# OC             89.687500
# AF             61.471698
# AS             37.045455

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby('continent').describe()['wine_servings'].sort_values(by = 'mean', ascending= False)
# Out:
#            count        mean        std   min   25%    50%     75%    max
# continent
# EU          45.0  142.222222  97.421738   0.0  59.0  128.0  195.00  370.0
# NA           2.0   92.000000  11.313708  84.0  88.0   92.0   96.00  100.0
# SA          12.0   62.416667  88.620189   1.0   3.0   12.0   98.50  221.0
# OC          16.0   35.625000  64.555790   0.0   1.0    8.5   23.25  212.0
# CA          21.0   18.095238  19.333662   1.0   5.0    9.0   28.00   71.0
# AF          53.0   16.264151  38.846419   0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034   0.0   0.0    1.0    8.00  123.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks.groupby('continent').mean().sort_values(by= 'total_litres_of_pure_alcohol', ascending= False)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# EU            193.777778       132.555556     142.222222
# NA            244.500000       140.000000      92.000000
# SA            175.083333       114.750000      62.416667
# CA            136.000000       168.190476      18.095238
# OC             89.687500        58.437500      35.625000
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
#
#            total_litres_of_pure_alcohol
# continent
# EU                             8.617778
# NA                             8.450000
# SA                             6.308333
# CA                             5.761905
# OC                             3.381250
# AF                             3.007547
# AS                             2.170455

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby('continent').median().sort_values(by= 'total_litres_of_pure_alcohol', ascending= False)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# EU                 219.0            122.0          128.0
# NA                 244.5            140.0           92.0
# SA                 162.5            108.5           12.0
# CA                 122.0            137.0            9.0
# AF                  32.0              3.0            2.0
# OC                  52.5             37.0            8.5
# AS                  17.5             16.0            1.0
#
#            total_litres_of_pure_alcohol
# continent
# EU                                10.00
# NA                                 8.45
# SA                                 6.85
# CA                                 6.20
# AF                                 2.30
# OC                                 1.75
# AS                                 1.20

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption per continent.

# %%
drinks.groupby('continent').aggregate(['mean', 'min', 'max'])['spirit_servings'].sort_values(by = 'mean', ascending= False)
# Out:
#                  mean  min  max
# continent
# CA         168.190476   68  438
# NA         140.000000  122  158
# EU         132.555556    0  373
# SA         114.750000   25  302
# AS          60.840909    0  326
# OC          58.437500    0  254
# AF          16.339623    0  152
